# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

from IPython.core.debugger import set_trace

total_pattern = re.compile('(\S+)\s+(\S+)')
pattern = re.compile('(\S+)\s+(\S+)\s+(\S+)')

# %%
feats = pd.read_csv("../System/fake_news_feats_train.csv")
fake = feats.loc[feats['class'] == 1]
real = feats.loc[feats['class'] == 0]

feats.head()
# Out:
#    index  superlatives  degree_adverbs  comparative_adverbs  proper_nouns  \
# 0      1      0.012270        0.100000             0.100000      0.297297
# 1      2      0.002611        0.130435             0.043478      0.226415
# 2      3      0.000000        0.000000             0.000000      0.209677
# 3      4      0.000000        0.250000             0.000000      0.400000
# 4      5      0.000000        0.125000             0.000000      0.226190
#
#       dates   numbers  fp_pronouns  negations  pos_emotion  ...    ap_num  \
# 0  0.000000  0.012270     0.357143   0.006135     0.000000  ...       0.0
# 1  0.005222  0.007833     0.041667   0.007833     0.002611  ...       0.0
# 2  0.000000  0.010101     0.600000   0.000000     0.005051  ...       0.0
# 3  0.003968  0.003968     0.111111   0.003968     0.000000  ...       0.0
# 4  0.010989  0.030220     0.137931   0.016484     0.013736  ...       1.0
#
#    ap_date  ap_title  alliteration  profanity  lexical_diversity  \
# 0      0.0       1.0      0.142857   0.000000           0.735294
# 1      0.0       1.0      0.111111   0.000000           0.612245
# 2      0.0       0.0      0.000000   0.000000           0.706731
# 3      0.0       1.0      0.181818   0.003802           0.627376
# 4      0.0       1.0      0.222222   0.002681           0.563003
#
#    lexical_density  function_words  spelling_errors  class
# 0         0.576471        0.423529         0.052941      1
# 1         0.579082        0.420918         0.028061      1
# 2         0.610577        0.389423         0.014423      1
# 3         0.653992        0.346008         0.045627      1
# 4         0.560322        0.439678         0.037534      1
#
# [5 rows x 45 columns]

# %%
superlatives = r'DAT|JJT|RGT|RRT'
degree_adverbs = r'RG(QV?|R|T)?'
comparative_adverbs = r'RGR|RRR'
proper_nouns = r'NP[12]'
dates = r'NP(D[12]|M[12])'
numbers = r'M[CDF]\w*'
fp_pronouns = r'PPI\w+'
negations = r'XX'

all_emotion = r'E[\w\.\+-]+'
emotion_general = r'E1[\+-]'
pos_emotion = r'E[2-6](\.[12])?\++'
neg_emotion = r'E[2-6](\.[12])?-+'
time_related = r'T[1-4][\.\d\+-]*'
sense_words = r'X3[\.\d\+-]*'
movement_words = r'M[1-6]'
relationships = r'S3.*'

spatial_words = r'RL|ND1|NNL[12]|M[78]'

# Imagination subject to change
inf_conjunctions = r'CC'
ima_conjunctions = r'CCB|CS'
conjunctions = r'C\w+'
inf_verb = r'VVN'
ima_verb = r'VV[^N]\w?|VM'
verbs = r'V\w+'
prepositions = r'I\w+'
articles = r'A\w+'
ima_determiners = r'DA1|DB\w?'
determiners = r'D\w+'
adjectives = r'J\w+'
nouns = r'N\w+'
pronouns = r'P\w+'
adverbs = r'R\w+'

exaggeration = r'A13\.[237]'    # Boosters, Maximisers, and Minimisers.
vague_degree = r'A13\.[145]'    # Non-specific, Approximators, Compromisers

re_punctuation = r'[\.\,\"\'\“\”\`\!\?]+'

# %%
def find_punctuation(indices):
    counts = dict()
    for i in indices:
        with open("../Tagged_Fake_News/{0}h/{0}h.txt".format(i)) as pos_file:
            text = pos_file.read().strip()
            instances = re.findall(re_punctuation, text)
            for p in instances:
                if p in counts:
                    counts[p] += (1 / len(text) / len(indices) * 100)
                else:
                    counts[p] = (1 / len(text) / len(indices) * 100)
                    
    return counts

def find_common_tags(regex, indices):
    directory = "../Tagged_Corpus"
    tags = dict()
    for i in indices:
        with open("../Tagged_Fake_News/{0}/{0}.txt.pos.sem.wap.fql".format(i)) as pos_file:
            lines = [line.strip() for line in pos_file]
            t = total_pattern.match(lines[0])
            total = int(t.group(2).strip())
            for line in lines:
                curr = line.strip()
                m = pattern.match(curr)
                
                if not m: continue
                
                word = m.group(1)
                tag = m.group(2)
                count = int(m.group(3)) / total / len(indices) * 100
                
                if tag in tags:
                    tags[tag].append((word, count))
                else:
                    tags[tag]= [(word, count)]
                        
        with open("../Tagged_Fake_News/{0}/{0}.txt.pos.sem.was.fql".format(i)) as sem_file:
            lines = [line.strip() for line in sem_file]
            t = total_pattern.match(lines[0])
            total = int(t.group(2).strip())
            for line in lines:
                curr = line.strip()
                m = pattern.match(curr)
                
                if not m: continue
                
                word = m.group(1)
                tag = m.group(2)
                count = int(m.group(3)) / total / len(indices) * 100
                
                if tag in tags:
                    tags[tag].append((word, count))
                else:
                    tags[tag]= [(word, count)]
                    
        words = []
        for tag in tags:
            if re.fullmatch(regex, tag):
                for word in tags[tag]:
                    words.append(word)
                        
    return words

# %%
target_tag = time_related
target_tag
# Out:
# 'NP[12]'

# %%
fake_words = find_common_tags(target_tag, fake.index.values + 1)

fake_words_pd = pd.DataFrame(fake_words, columns=['word','fake_count'])
fake_words_pd = fake_words_pd.groupby('word').sum()

fake_words_pd.sort_values("fake_count", ascending=False)
# Out:
#                           fake_count
# word
# Donald_trump                0.324573
# Clinton                     0.237954
# Obama                       0.226432
# Hillary                     0.184522
# Hillary_Clinton             0.171836
# United_States               0.134888
# ISIS                        0.123341
# America                     0.103687
# U.S.                        0.095935
# White_house                 0.090857
# Clintons                    0.081043
# Palin                       0.058128
# Donald                      0.056823
# Obamas                      0.054372
# Cruz                        0.052812
# Washington                  0.052476
# Bill_Clinton                0.050496
# US                          0.049330
# Ted_Cruz                    0.048840
# Syria                       0.047319
# Facebook                    0.044473
# Canada                      0.044036
# FBI                         0.042894
# Sanders                     0.039865
# Turkey                      0.037140
# Hillarys                    0.035636
# Bill                        0.035432
# Russia                      0.030702
# Mexico                      0.029502
# New_York                    0.028624
# ...                              ...
# Balch                       0.000505
# Hispanics                   0.000505
# CNA                         0.000505
# Lawrence                    0.000505
# Jehovahs_witnesses          0.000505
# Sharia                      0.000505
# Francis_Bellamy             0.000505
# Intelius                    0.000465
# Schoffstall                 0.000465
# Schoffstalls                0.000465
# Capitol_Hillon              0.000465
# Humayun_Khan                0.000465
# Jeb_Bush                    0.000465
# Katelyn_Polantz             0.000465
# Joe_Schoffstall             0.000465
# Robert_Kyle                 0.000465
# Raymond                     0.000465
# Chuck_Grassley              0.000465
# R-SC                        0.000465
# Politico                    0.000465
# Grassleywas                 0.000465
# Ghazala_Khan                0.000465
# George_Stephanopouloswho    0.000465
# Law.com                     0.000465
# Patrick_Howley              0.000465
# Lindsey_Graham              0.000465
# Walid_Shoebat               0.000465
# Donald_Trumpthe             0.000465
# McAfee                      0.000465
# mega-D.C.                   0.000465
#
# [970 rows x 1 columns]

# %%
real_words = find_common_tags(target_tag, real.index.values + 1)

real_words_pd = pd.DataFrame(real_words, columns=['word','real_count'])
real_words_pd = real_words_pd.groupby('word').sum()

real_words_pd.sort_values("real_count", ascending=False)
# Out:
#                                real_count
# word
# Donald_trump                     0.241445
# Clinton                          0.155643
# Obama                            0.125568
# U.S.                             0.118571
# Hillary_Clinton                  0.096903
# Russia                           0.088400
# FBI                              0.077381
# White_house                      0.074447
# America                          0.063770
# Washington                       0.062028
# Texas                            0.046980
# Putin                            0.046799
# United_States                    0.045816
# Clintons                         0.038360
# New_York                         0.035371
# Sanders                          0.035178
# Tillerson                        0.032127
# Florida                          0.030298
# Hillary                          0.029410
# CIA                              0.028826
# Bernie_Sanders                   0.028747
# US                               0.028688
# DNC                              0.028388
# Comey                            0.027618
# Mexico                           0.027329
# Donald                           0.027318
# China                            0.026657
# Perez                            0.025296
# Donald_J._trump                  0.024134
# NBC                              0.023944
# ...                                   ...
# Kevin_Williamson                 0.000111
# Jeff_Swensen/Getty               0.000111
# A._Philip_Randolph               0.000111
# Bayard_Rustin                    0.000111
# Katy_Textor                      0.000111
# John_Yoo                         0.000111
# Tannen_Maury/AFP/Getty           0.000111
# Stewart                          0.000111
# Dropp                            0.000105
# Karen_Stenner                    0.000105
# Jonathan_Haidt                   0.000105
# Alabama_Mark_Wallheiser/Getty    0.000105
# Justin_Sullivan/Getty            0.000105
# Adam_Petrihos                    0.000105
# Doogie_Howser                    0.000105
# Jonathan_Weiler                  0.000105
# Michael_Ciaglo/Pool/Getty        0.000105
# Venus                            0.000105
# Brendan_Hoffman/Getty            0.000105
# Texas_Tom_Pennington/Getty       0.000105
# Theodor_Adorno                   0.000105
# Kyle_Dropp                       0.000105
# Andrew_Renneisen/Getty           0.000105
# Gulf_coast                       0.000105
# Marc_Hetherington                0.000105
# Mars                             0.000105
# SUNY_Stonybrook                  0.000105
# Dartmouth                        0.000105
# Scott_Olson/Getty                0.000105
# Vanderbilt_university            0.000105
#
# [1867 rows x 1 columns]

# %%
word_freqs = fake_words_pd.join(real_words_pd, how='outer')
word_freqs = word_freqs.fillna(0)

word_freqs = word_freqs.sort_values("fake_count", ascending=False)
word_freqs
# Out:
#                          fake_count  real_count
# word
# Donald_trump               0.324573    0.241445
# Clinton                    0.237954    0.155643
# Obama                      0.226432    0.125568
# Hillary                    0.184522    0.029410
# Hillary_Clinton            0.171836    0.096903
# United_States              0.134888    0.045816
# ISIS                       0.123341    0.005425
# America                    0.103687    0.063770
# U.S.                       0.095935    0.118571
# White_house                0.090857    0.074447
# Clintons                   0.081043    0.038360
# Palin                      0.058128    0.000000
# Donald                     0.056823    0.027318
# Obamas                     0.054372    0.017648
# Cruz                       0.052812    0.003199
# Washington                 0.052476    0.062028
# Bill_Clinton               0.050496    0.018961
# US                         0.049330    0.028688
# Ted_Cruz                   0.048840    0.005264
# Syria                      0.047319    0.008855
# Facebook                   0.044473    0.008149
# Canada                     0.044036    0.006728
# FBI                        0.042894    0.077381
# Sanders                    0.039865    0.035178
# Turkey                     0.037140    0.016321
# Hillarys                   0.035636    0.002185
# Bill                       0.035432    0.002260
# Russia                     0.030702    0.088400
# Mexico                     0.029502    0.027329
# New_York                   0.028624    0.035371
# ...                             ...         ...
# Ivanka                     0.000000    0.002069
# Jasper_Colt                0.000000    0.000349
# James_Glassman             0.000000    0.000407
# Jason_Chaffetz             0.000000    0.001283
# Jarl                       0.000000    0.002676
# Japan                      0.000000    0.002369
# Janet_Yellen               0.000000    0.001262
# Jane_Doe                   0.000000    0.004354
# Jane                       0.000000    0.001814
# Jammeh                     0.000000    0.006068
# James_Mattis               0.000000    0.008646
# James_Madison              0.000000    0.002008
# James_Lankford             0.000000    0.000578
# James_Langdon              0.000000    0.000318
# James_Kunder               0.000000    0.000407
# James_Clapper              0.000000    0.000712
# JERUSALEM                  0.000000    0.001675
# James_Bowles               0.000000    0.001193
# Jake_Sullivan              0.000000    0.000253
# Jacqueline_Savitz          0.000000    0.002190
# Jacobs                     0.000000    0.001029
# Jackie_Enterline_Fekeci    0.000000    0.002170
# Jack_goldsmith             0.000000    0.000253
# Jack_Reed                  0.000000    0.001290
# Jack_McGregor              0.000000    0.000407
# Jabin_Botsford             0.000000    0.002561
# JPMorgan                   0.000000    0.001262
# JONATHAN_drake             0.000000    0.000163
# JFK                        0.000000    0.000318
# them--Bret_Chiafalo        0.000000    0.001830
#
# [2540 rows x 2 columns]

# %%
fig, ax = plt.subplots()

top_20 = word_freqs.head(15)
top_20.plot.bar(ax=ax)
ax.xaxis.label.set_visible(False)
plt.show()

# %%
fake_punct = find_punctuation(fake.index.values + 1)
real_punct = find_punctuation(real.index.values + 1)

# %%
fake_punct_pd = pd.DataFrame.from_dict(fake_punct, orient='index')
fake_punct_pd.columns = ['fake_count']
fake_punct_pd = af_punct_pd.sort_values('fake_count', ascending=False)

real_punct_pd = pd.DataFrame.from_dict(real_punct, orient='index')
real_punct_pd.columns = ['real_count']
real_punct_pd = real_punct_pd.sort_values('real_count', ascending=False)

punct_freqs = fake_punct_pd.join(real_punct_pd, how='outer')
punct_freqs = punct_freqs.fillna(0)

punct_freqs = punct_freqs.sort_values("fake_count", ascending=False)
punct_freqs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c736dbd3e7e6> in <module>()
#       1 fake_punct_pd = pd.DataFrame.from_dict(fake_punct, orient='index')
#       2 fake_punct_pd.columns = ['fake_count']
# ----> 3 fake_punct_pd = af_punct_pd.sort_values('fake_count', ascending=False)
#       4
#       5 real_punct_pd = pd.DataFrame.from_dict(real_punct, orient='index')
#
# NameError: name 'af_punct_pd' is not defined

# %%
punct_freqs.head(20).plot.bar()
plt.show()
