# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

from IPython.core.debugger import set_trace

total_pattern = re.compile('(\S+)\s+(\S+)')
pattern = re.compile('(\S+)\s+(\S+)\s+(\S+)')

# %%
feats = pd.read_csv("../System/fake_news_feats_train.csv")
fake = feats.loc[feats['class'] == 1]
real = feats.loc[feats['class'] == 0]

feats.head()
# Out:
#    index  superlatives  degree_adverbs  comparative_adverbs  proper_nouns  \
# 0      1      0.012270        0.100000             0.100000      0.297297
# 1      2      0.002611        0.130435             0.043478      0.226415
# 2      3      0.000000        0.000000             0.000000      0.209677
# 3      4      0.000000        0.250000             0.000000      0.400000
# 4      5      0.000000        0.125000             0.000000      0.226190
#
#       dates   numbers  fp_pronouns  negations  pos_emotion  ...    ap_num  \
# 0  0.000000  0.012270     0.357143   0.006135     0.000000  ...       0.0
# 1  0.005222  0.007833     0.041667   0.007833     0.002611  ...       0.0
# 2  0.000000  0.010101     0.600000   0.000000     0.005051  ...       0.0
# 3  0.003968  0.003968     0.111111   0.003968     0.000000  ...       0.0
# 4  0.010989  0.030220     0.137931   0.016484     0.013736  ...       1.0
#
#    ap_date  ap_title  alliteration  profanity  lexical_diversity  \
# 0      0.0       1.0      0.142857   0.000000           0.735294
# 1      0.0       1.0      0.111111   0.000000           0.612245
# 2      0.0       0.0      0.000000   0.000000           0.706731
# 3      0.0       1.0      0.181818   0.003802           0.627376
# 4      0.0       1.0      0.222222   0.002681           0.563003
#
#    lexical_density  function_words  spelling_errors  class
# 0         0.576471        0.423529         0.052941      1
# 1         0.579082        0.420918         0.028061      1
# 2         0.610577        0.389423         0.014423      1
# 3         0.653992        0.346008         0.045627      1
# 4         0.560322        0.439678         0.037534      1
#
# [5 rows x 45 columns]

# %%
superlatives = r'DAT|JJT|RGT|RRT'
degree_adverbs = r'RG(QV?|R|T)?'
comparative_adverbs = r'RGR|RRR'
proper_nouns = r'NP[12]'
dates = r'NP(D[12]|M[12])'
numbers = r'M[CDF]\w*'
fp_pronouns = r'PPI\w+'
negations = r'XX'

all_emotion = r'E[\w\.\+-]+'
emotion_general = r'E1[\+-]'
pos_emotion = r'E[2-6](\.[12])?\++'
neg_emotion = r'E[2-6](\.[12])?-+'
time_related = r'T[1-4][\.\d\+-]*'
sense_words = r'X3[\.\d\+-]*'
movement_words = r'M[1-6]'
relationships = r'S3.*'

spatial_words = r'RL|ND1|NNL[12]|M[78]'

# Imagination subject to change
inf_conjunctions = r'CC'
ima_conjunctions = r'CCB|CS'
conjunctions = r'C\w+'
inf_verb = r'VVN'
ima_verb = r'VV[^N]\w?|VM'
verbs = r'V\w+'
prepositions = r'I\w+'
articles = r'A\w+'
ima_determiners = r'DA1|DB\w?'
determiners = r'D\w+'
adjectives = r'J\w+'
nouns = r'N\w+'
pronouns = r'P\w+'
adverbs = r'R\w+'

exaggeration = r'A13\.[237]'    # Boosters, Maximisers, and Minimisers.
vague_degree = r'A13\.[145]'    # Non-specific, Approximators, Compromisers

re_punctuation = r'[\.\,\"\'\“\”\`\!\?]+'

# %%
def find_punctuation(indices):
    counts = dict()
    for i in indices:
        with open("../Tagged_Fake_News/{0}h/{0}h.txt".format(i)) as pos_file:
            text = pos_file.read().strip()
            instances = re.findall(re_punctuation, text)
            for p in instances:
                if p in counts:
                    counts[p] += (1 / len(text) / len(indices) * 100)
                else:
                    counts[p] = (1 / len(text) / len(indices) * 100)
                    
    return counts

def find_common_tags(regex, indices):
    directory = "../Tagged_Corpus"
    tags = dict()
    for i in indices:
        with open("../Tagged_Fake_News/{0}/{0}.txt.pos.sem.wap.fql".format(i)) as pos_file:
            lines = [line.strip() for line in pos_file]
            t = total_pattern.match(lines[0])
            total = int(t.group(2).strip())
            for line in lines:
                curr = line.strip()
                m = pattern.match(curr)
                
                if not m: continue
                
                word = m.group(1)
                tag = m.group(2)
                count = int(m.group(3)) / total / len(indices) * 100
                
                if tag in tags:
                    tags[tag].append((word, count))
                else:
                    tags[tag]= [(word, count)]
                        
        with open("../Tagged_Fake_News/{0}/{0}.txt.pos.sem.was.fql".format(i)) as sem_file:
            lines = [line.strip() for line in sem_file]
            t = total_pattern.match(lines[0])
            total = int(t.group(2).strip())
            for line in lines:
                curr = line.strip()
                m = pattern.match(curr)
                
                if not m: continue
                
                word = m.group(1)
                tag = m.group(2)
                count = int(m.group(3)) / total / len(indices) * 100
                
                if tag in tags:
                    tags[tag].append((word, count))
                else:
                    tags[tag]= [(word, count)]
                    
        words = []
        for tag in tags:
            if re.fullmatch(regex, tag):
                for word in tags[tag]:
                    words.append(word)
                        
    return words

# %%
target_tag = time_related
target_tag
# Out:
# 'T[1-4][\\.\\d\\+-]*'

# %%
fake_words = find_common_tags(target_tag, fake.index.values + 1)

fake_words_pd = pd.DataFrame(fake_words, columns=['word','fake_count'])
fake_words_pd = fake_words_pd.groupby('word').sum()

fake_words_pd.sort_values("fake_count", ascending=False)
# Out:
#                         fake_count
# word
# will                      0.340271
# now                       0.140739
# former                    0.125803
# time                      0.102929
# new                       0.101892
# years                     0.095029
# sources                   0.077962
# today                     0.072557
# week                      0.071174
# already                   0.066887
# never                     0.061840
# still                     0.055268
# going_to                  0.048757
# day                       0.048524
# recent                    0.047931
# source                    0.046654
# yet                       0.038389
# later                     0.036679
# stop                      0.032156
# future                    0.031677
# old                       0.029960
# history                   0.029918
# days                      0.029567
# ever                      0.027561
# month                     0.026746
# Monday                    0.026482
# recently                  0.026443
# Tuesday                   0.026143
# currently                 0.026005
# year                      0.025859
# ...                            ...
# present_day               0.000663
# establish                 0.000663
# over_20                   0.000647
# defunct                   0.000647
# last_six_years            0.000647
# April                     0.000647
# minors                    0.000647
# high-fives                0.000636
# the_whole_time            0.000636
# over_the_past_40_years    0.000607
# middle-aged               0.000607
# 11                        0.000607
# 27                        0.000607
# long-time                 0.000607
# ended                     0.000607
# instigated                0.000607
# March_1979                0.000607
# May_28                    0.000607
# get_into                  0.000607
# three_to_five             0.000513
# 24_hours_a_day            0.000513
# invoke                    0.000513
# came_on                   0.000505
# 10pm                      0.000505
# October_20th              0.000505
# February_2016             0.000465
# nights                    0.000465
# few_weeks_ago             0.000465
# 2000_to_2007              0.000465
# to_this_day               0.000465
#
# [450 rows x 1 columns]

# %%
real_words = find_common_tags(target_tag, real.index.values + 1)

real_words_pd = pd.DataFrame(real_words, columns=['word','real_count'])
real_words_pd = real_words_pd.groupby('word').sum()

real_words_pd.sort_values("real_count", ascending=False)
# Out:
#                   real_count
# word
# will                0.367701
# former              0.165209
# new                 0.121108
# now                 0.102308
# years               0.090951
# going_to            0.084164
# still               0.074521
# time                0.069998
# never               0.068779
# foundation          0.067519
# year                0.057759
# sessions            0.049528
# days                0.045336
# future              0.044521
# day                 0.044454
# Monday              0.042003
# Tuesday             0.041151
# last_week           0.041050
# already             0.041006
# week                0.039932
# history             0.037034
# yet                 0.036813
# ever                0.036734
# recently            0.034603
# recent              0.034369
# repeal              0.033510
# months              0.033264
# Friday              0.032729
# Sunday              0.032547
# today               0.028998
# ...                      ...
# September_2015      0.000111
# last_October        0.000111
# last_December       0.000111
# give_up             0.000111
# juncture            0.000111
# August_12           0.000111
# June_2015           0.000111
# over_20             0.000111
# December_2015       0.000111
# five-year-old       0.000111
# regenerate          0.000111
# relent              0.000111
# sixty_years_ago     0.000111
# origins             0.000111
# culminated          0.000111
# at_present          0.000111
# February_25         0.000105
# early_2000s         0.000105
# last_September      0.000105
# coinciding          0.000105
# September_2001      0.000105
# imminent            0.000105
# at_all_times        0.000105
# winter              0.000105
# 75                  0.000105
# longer_term         0.000105
# mid-20th_century    0.000105
# presently           0.000105
# next_few_decades    0.000105
# nonstop             0.000105
#
# [765 rows x 1 columns]

# %%
word_freqs = fake_words_pd.join(real_words_pd, how='outer')
word_freqs = word_freqs.fillna(0)

word_freqs = word_freqs.sort_values("fake_count", ascending=False)
word_freqs
# Out:
#                 fake_count  real_count
# word
# will              0.340271    0.367701
# now               0.140739    0.102308
# former            0.125803    0.165209
# time              0.102929    0.069998
# new               0.101892    0.121108
# years             0.095029    0.090951
# sources           0.077962    0.016771
# today             0.072557    0.028998
# week              0.071174    0.039932
# already           0.066887    0.041006
# never             0.061840    0.068779
# still             0.055268    0.074521
# going_to          0.048757    0.084164
# day               0.048524    0.044454
# recent            0.047931    0.034369
# source            0.046654    0.022914
# yet               0.038389    0.036813
# later             0.036679    0.024609
# stop              0.032156    0.027401
# future            0.031677    0.044521
# old               0.029960    0.018427
# history           0.029918    0.037034
# days              0.029567    0.045336
# ever              0.027561    0.036734
# month             0.026746    0.023412
# Monday            0.026482    0.042003
# recently          0.026443    0.034603
# Tuesday           0.026143    0.041151
# currently         0.026005    0.008271
# year              0.025859    0.057759
# ...                    ...         ...
# deferred          0.000000    0.000604
# delay             0.000000    0.004781
# delayed           0.000000    0.001318
# demise            0.000000    0.000726
# drag_on           0.000000    0.000726
# duration          0.000000    0.000869
# dusk              0.000000    0.001279
# dying_off         0.000000    0.000515
# continuous        0.000000    0.002321
# continuation      0.000000    0.001238
# continually       0.000000    0.001982
# contemporary      0.000000    0.000111
# be_up             0.000000    0.000587
# briefly           0.000000    0.000699
# bygone            0.000000    0.001238
# bygones           0.000000    0.001155
# cancellations     0.000000    0.001029
# carry_on          0.000000    0.000424
# ceases            0.000000    0.000886
# centenary         0.000000    0.000334
# christmas_day     0.000000    0.003034
# closed_down       0.000000    0.001517
# co-founder        0.000000    0.000904
# coincide          0.000000    0.000421
# coinciding        0.000000    0.000105
# come_to_an_end    0.000000    0.000481
# completes         0.000000    0.001740
# constant          0.000000    0.001945
# constantly        0.000000    0.003988
# fizzles           0.000000    0.002673
#
# [960 rows x 2 columns]

# %%
fig, ax = plt.subplots()

top_20 = word_freqs.head(15)
top_20.plot.bar(ax=ax)
ax.xaxis.label.set_visible(False)
plt.show()

# %%
fake_punct = find_punctuation(fake.index.values + 1)
real_punct = find_punctuation(real.index.values + 1)

# %%
fake_punct_pd = pd.DataFrame.from_dict(fake_punct, orient='index')
fake_punct_pd.columns = ['fake_count']
fake_punct_pd = af_punct_pd.sort_values('fake_count', ascending=False)

real_punct_pd = pd.DataFrame.from_dict(real_punct, orient='index')
real_punct_pd.columns = ['real_count']
real_punct_pd = real_punct_pd.sort_values('real_count', ascending=False)

punct_freqs = fake_punct_pd.join(real_punct_pd, how='outer')
punct_freqs = punct_freqs.fillna(0)

punct_freqs = punct_freqs.sort_values("fake_count", ascending=False)
punct_freqs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c736dbd3e7e6> in <module>()
#       1 fake_punct_pd = pd.DataFrame.from_dict(fake_punct, orient='index')
#       2 fake_punct_pd.columns = ['fake_count']
# ----> 3 fake_punct_pd = af_punct_pd.sort_values('fake_count', ascending=False)
#       4
#       5 real_punct_pd = pd.DataFrame.from_dict(real_punct, orient='index')
#
# NameError: name 'af_punct_pd' is not defined

# %%
punct_freqs.head(20).plot.bar()
plt.show()
